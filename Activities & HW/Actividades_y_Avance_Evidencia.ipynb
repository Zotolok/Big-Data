# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import matplotlib.pyplot as plt

# %%
os.chdir('/content/drive/My Drive/')

# %%
img = plt.imread('TecMi.png')

# %%
plt.imshow(img)

# %%
from IPython.display import Image #Biblioteca para mostrar imágenes.

# %%
Image('TecMi.png')

# %%
Image("TecMi.png", width=100, height=100)

# %% [markdown]
# #Actividad 1

# %% [markdown]
# Contenido

# %% [markdown]
# www.youtube.com

# %%
import numpy as np

# %% [markdown]
# #Actividad 2

# %% [markdown]
# #Actividad 3

# %% [markdown]
# #Actividad 4

# %% [markdown]
# #Actividad 5

# %% [markdown]
# #Avance de Evidencia 1

# %% [markdown]
# #Titanic

# %%
# !pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post9-py3-none-any.whl size=2952 sha256=0a85592e27113c7efac650240b8f7cf25bc29d58c1a5800e048503d12a6a6c50
#   Stored in directory: /root/.cache/pip/wheels/33/a3/d2/092b519e9522b4c91608b7dcec0dd9051fa1bff4c45f4502d1
# Successfully built sklearn
# ...
